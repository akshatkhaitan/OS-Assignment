# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("C:/Users/tanma/Downloads/p1.csv")

# %%
df2 = pd.read_csv("C:/Users/tanma/Downloads/p2.csv")

# %%
df1
# Out:
#         5     1      28848      27739      27519
# 0       5     2     103356     171706      30568
# 1       5     3      69658     151398      55554
# 2       5     4      83676     197301      66606
# 3       5     5     128228     171954      70225
# 4       5     6    1735296     248938     105400
# ...    ..   ...        ...        ...        ...
# 19244  50  4996  134001899  212181531  133126204
# 19245  50  4997  136257332  213195484  131921733
# 19246  50  4998  136528958  216178420  134482430
# 19247  50  4999  135172679  214878218  134365828
# 19248  50  5000  142600422  222649730  141191562
#
# [19249 rows x 5 columns]

# %%
df2
# Out:
#        5     1    184864    189913    151505
# 0      5     2    138104    171779    117363
# 1      5     3    138824    203096    126154
# 2      5     4    125920    177178    121372
# 3      5     5    198488    324647    194207
# 4      5     6    202051    316331    199695
# ...   ..   ...       ...       ...       ...
# 9619  50  2496  38574730  59640915  38018075
# 9620  50  2497  41807148  62457208  40662816
# 9621  50  2498  39058770  61197199  39058410
# 9622  50  2499  41748709  64115973  40648801
# 9623  50  2500  39463902  61333932  39004164
#
# [9624 rows x 5 columns]

# %%
df = df1.groupby('5')
df

# %%
sns.set(rc={'figure.figsize':(15,11)})
sns.set_style("darkgrid")

# %%
for i in range(5,51,5):
   kt = pd.DataFrame()
   cond_ = (df1['5'] == i) & (df1['1']<60)
   kt = df1.loc[cond_,:]
   sns.lineplot(x = kt['1'],y = kt['27519'])
plt.legend(['5','10','15','20','25','30','35','40','45','50'])

# %%
cond_ = (df1['5'] == 5)
kt = df1.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['27519'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='27519'>

# %%
cond_ = (df1['5'] == 10)
kt = df1.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['27519'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='27519'>

# %%
cond_ = (df1['5'] == 15)
kt = df1.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['27519'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='27519'>

# %%
cond_ = (df1['5'] == 20)
kt = df1.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['27519'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='27519'>

# %%
cond_ = (df1['5'] == 25)
kt = df1.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['27519'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='27519'>

# %%
cond_ = (df1['5'] == 30)
kt = df1.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['27519'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='27519'>

# %%
cond_ = (df1['5'] == 35)
kt = df1.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['27519'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='27519'>

# %%
cond_ = (df1['5'] == 40)
kt = df1.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['27519'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='27519'>

# %%
cond_ = (df1['5'] == 45)
kt = df1.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['27519'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='27519'>

# %%
cond_ = (df1['5'] == 50)
kt = df1.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['27519'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='27519'>

# %%
cond_ = (df2['5'] == 5)
kt = df2.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['151505'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='151505'>

# %%
cond_ = (df2['5'] == 10)
kt = df2.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['151505'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='151505'>

# %%
cond_ = (df2['5'] == 15)
kt = df2.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['151505'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='151505'>

# %%
cond_ = (df2['5'] == 20)
kt = df2.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['151505'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='151505'>

# %%
cond_ = (df2['5'] == 25)
kt = df2.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['151505'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='151505'>

# %%
cond_ = (df2['5'] == 30)
kt = df2.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['151505'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='151505'>

# %%
cond_ = (df2['5'] == 35)
kt = df2.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['151505'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='151505'>

# %%
cond_ = (df2['5'] == 40)
kt = df2.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['151505'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='151505'>

# %%
cond_ = (df2['5'] == 45)
kt = df2.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['151505'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='151505'>

# %%
cond_ = (df2['5'] == 50)
kt = df2.loc[cond_,:]
sns.lineplot(x = kt['1'],y = kt['151505'])
# Out:
# <AxesSubplot:xlabel='1', ylabel='151505'>

# %%
for i in range(5,51,5):
   kt = pd.DataFrame()
   cond_ = (df2['5'] == i) & (df2['1'] < 60)
   kt = df2.loc[cond_,:]
   sns.lineplot(x = kt['1'],y = kt['151505'])
plt.legend(['5','10','15','20','25','30','35','40','45','50'])

# %%
df3 = pd.read_csv("C:/Users/tanma/Downloads/s.csv")

# %%
df3
# Out:
#     tq  sizes_RT  p1_turnaround  p2_turnaround  p1_waiting_time  \
# 0    1         5         226224         542804           114712
# 1    1        10         196587         562040            33844
# 2    1        15         229723         916586           512294
# 3    1        20          56866         666843           224372
# 4    1        25         283389        1407809          1105812
# 5    1        30          74735         742206           470505
# 6    1        35          83409         770380           988276
# 7    1        40          89073         726779           712149
# 8    1        45         547749        2237331          2040428
# 9    1        50         105495        1187514          1075195
# 10   2         5         177898         834140            66111
# 11   2        10          50047         471972           491282
# 12   2        15          56050         606184           572573
# 13   2        20          94654        1320482           595733
# ...

# %%
cond_ = (df3['tq'] == 1)
kt = df3.loc[cond_,:]
plt.ylabel("Turnaround_time")
plt.xlabel("input_size")
sns.lineplot(x = kt['sizes_RT'],y = kt['p1_turnaround'])
sns.lineplot(x = kt['sizes_RT'],y = kt['p2_turnaround'])
# Out:
# <AxesSubplot:xlabel='input_size', ylabel='Turnaround_time'>

# %%
cond_ = (df3['tq'] == 2)
kt = df3.loc[cond_,:]
plt.ylabel("Turnaround_time")
plt.xlabel("input_size")
sns.lineplot(x = kt['sizes_RT'],y = kt['p1_turnaround'])
sns.lineplot(x = kt['sizes_RT'],y = kt['p2_turnaround'])
# Out:
# <AxesSubplot:xlabel='input_size', ylabel='Turnaround_time'>

# %%
cond_ = (df3['tq'] == 1)
kt = df3.loc[cond_,:]
plt.ylabel("Waiting_Time")
plt.xlabel("input_size")
sns.lineplot(x = kt['sizes_RT'],y = kt['p1_waiting_time'])
sns.lineplot(x = kt['sizes_RT'],y = kt['p2_waiting_time'])
# Out:
# <AxesSubplot:xlabel='input_size', ylabel='Waiting_Time'>

# %%
cond_ = (df3['tq'] == 2)
kt = df3.loc[cond_,:]
plt.ylabel("Waiting_Time")
plt.xlabel("input_size")
sns.lineplot(x = kt['sizes_RT'],y = kt['p1_waiting_time'])
sns.lineplot(x = kt['sizes_RT'],y = kt['p2_waiting_time'])
# Out:
# <AxesSubplot:xlabel='input_size', ylabel='Waiting_Time'>

# %%
cond_ = (df3['tq'] == 1)
kt = df3.loc[cond_,:]
plt.ylabel("context_switch")
plt.xlabel("input_size")
sns.lineplot(x = kt['sizes_RT'],y = abs(kt['p1_waiting_time']-kt['p2_waiting_time'])/2)
cond_ = (df3['tq'] == 2)
kt = df3.loc[cond_,:]
sns.lineplot(x = kt['sizes_RT'],y = abs(kt['p1_waiting_time']-kt['p2_waiting_time'])/2)
# Out:
# <AxesSubplot:xlabel='input_size', ylabel='context_switch'>
